# %% [markdown]
# # Medical Appointment No Shows Case Study
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
#     <ul>
#     <li><a href="#assess">Data Assessing</a></li>
#     <li><a href="#clean">Data Cleaning</a></li>
#    </ul>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# > The dataset we are working with is [Medical Appointment No Shows Dataset](https://www.kaggle.com/joniarroba/noshowappointments) which collects information from 100k medical appointments in Brazil and is focused on the question of whether or not patients show up for their appointment. A number of characteristics about the patient are included in each row.

# %%
#Importing necessary packages.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
% matplotlib inline

# %%
#loading the dataset into pandas dataframe.
df = pd.read_csv("noshowappointments-kagglev2-may-2016.csv")
df.sample(10)
# Out:
#            PatientId  AppointmentID Gender          ScheduledDay  \
# 84224   7.213114e+13        5773800      M  2016-06-06T07:32:13Z
# 7908    8.199334e+14        5705660      M  2016-05-17T07:23:15Z
# 55579   4.152665e+13        5632519      F  2016-04-28T08:06:13Z
# 39633   4.666633e+13        5681028      F  2016-05-10T13:26:19Z
# 106654  4.331792e+13        5774181      M  2016-06-06T07:57:21Z
# 41575   3.944859e+12        5716180      F  2016-05-18T16:05:11Z
# 101586  2.358298e+13        5724949      F  2016-05-20T10:21:07Z
# 56798   4.467149e+14        5665302      F  2016-05-05T14:13:51Z
# 109004  2.676449e+12        5750904      M  2016-05-31T09:28:11Z
# 37990   9.165441e+13        5713061      F  2016-05-18T09:40:05Z
#
#               AppointmentDay  Age      Neighbourhood  Scholarship  \
# 84224   2016-06-06T00:00:00Z   33        RESISTÊNCIA            0
# 7908    2016-05-17T00:00:00Z    3  JESUS DE NAZARETH            0
# 55579   2016-05-20T00:00:00Z   62           DA PENHA            1
# 39633   2016-05-17T00:00:00Z   16         INHANGUETÁ            1
# 106654  2016-06-06T00:00:00Z   43       SÃO BENEDITO            0
# 41575   2016-05-20T00:00:00Z   54          CARATOÍRA            0
# 101586  2016-06-08T00:00:00Z   36           GURIGICA            1
# 56798   2016-05-09T00:00:00Z   35         TABUAZEIRO            0
# 109004  2016-06-06T00:00:00Z   13  JESUS DE NAZARETH            0
# 37990   2016-05-18T00:00:00Z   79     FORTE SÃO JOÃO            0
#
#         Hipertension  Diabetes  Alcoholism  Handcap  SMS_received No-show
# 84224              0         0           0        0             0      No
# 7908               0         0           0        0             0      No
# 55579              0         0           0        0             0     Yes
# 39633              0         0           0        0             0      No
# 106654             0         0           0        0             0      No
# 41575              0         0           0        0             0      No
# 101586             1         0           0        0             1      No
# 56798              0         0           0        0             0      No
# 109004             0         0           0        1             1      No
# 37990              1         0           0        0             0      No

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
# > In this section we will access and clean our dataset's issues to promote findings of our analysis process.

# %% [markdown]
# <a id='assess'></a>
# ### Data Assessing
# > In this section we will access our dataset for quality & tidiness issues

# %%
df.shape
# Out:
# (110527, 14)

# %%
#checking the df for any null values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null object
# AppointmentDay    110527 non-null object
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %% [markdown]
# - no null values which is good, now lets check for other quality and tidiness issues.
#
# - one small typo is `Hipertension` column rather than 'Hypertension', I know that it's Hipertensión in spanish but it will cause no harm to change the name of the column.
#
# - `ScheduledDay` and `AppointmentDay` columns are of object type rather than datetime type.

# %%
#check the values of each column in the df.
for column in df.columns:
    print(df[column].value_counts())
# Out:
# 8.221459e+14    88
# 9.963767e+10    84
# 2.688613e+13    70
# 3.353478e+13    65
# 2.584244e+11    62
# 7.579746e+13    62
# 8.713749e+14    62
# 6.264199e+12    62
# 6.684488e+13    57
# 8.722785e+11    55
# 8.923969e+13    54
# 8.435224e+09    51
# 8.534397e+14    50
# 1.447997e+13    46
# 6.543360e+13    46
# 8.189452e+13    42
# 9.452745e+12    42
# 1.882323e+14    40
# 9.496197e+12    38
# 2.271580e+12    38
# 1.336493e+13    37
# 1.484143e+12    35
# 8.883500e+13    34
# 9.861628e+14    34
# 7.124589e+14    33
# 4.167557e+14    30
# 6.128878e+12    30
# 8.121397e+13    29
# 8.634164e+12    24
# 3.699499e+13    23
#                 ..
# 6.375629e+12     1
# 9.369127e+12     1
# 5.375556e+14     1
# 1.662184e+11     1
# 7.234615e+13     1
# 9.649990e+12     1
# 6.912783e+10     1
# 1.954265e+13     1
# 2.736377e+10     1
# 5.532694e+11     1
# 7.149583e+12     1
# 8.676752e+13     1
# 7.838359e+13     1
# 5.962625e+11     1
# 4.919862e+13     1
# 3.477350e+14     1
# 1.626595e+13     1
# 7.794917e+12     1
# 1.161950e+13     1
# 5.615364e+14     1
# 4.355592e+11     1
# 1.321328e+12     1
# 1.751987e+13     1
# 4.262579e+13     1
# 3.115681e+13     1
# 1.222828e+13     1
# 6.821231e+11     1
# 7.163981e+14     1
# 9.798964e+14     1
# 2.724571e+11     1
# Name: PatientId, Length: 62299, dtype: int64
# 5769215    1
# 5731652    1
# 5707080    1
# 5702986    1
# 5715276    1
# 5717325    1
# 5711182    1
# 5758289    1
# 5762391    1
# 5741913    1
# 5483871    1
# 5660001    1
# 5653858    1
# 5666148    1
# 5668197    1
# 5641576    1
# 5639531    1
# 5649772    1
# 5645678    1
# 5647727    1
# 5692785    1
# 5686642    1
# 5694838    1
# 5696887    1
# 5674360    1
# 5733701    1
# 5651786    1
# 5672315    1
# 5719362    1
# 5672187    1
#           ..
# 5744033    1
# 5748131    1
# 5739943    1
# 5672324    1
# 5682563    1
# 5680512    1
# 5782866    1
# 5496110    1
# 5713200    1
# 5711153    1
# 5717298    1
# 5709110    1
# 5707063    1
# 5729592    1
# 5463358    1
# 5565768    1
# 5776721    1
# 5789023    1
# 5590396    1
# 5606756    1
# 5608807    1
# 5635434    1
# 5621101    1
# 5686470    1
# 5582192    1
# 5586290    1
# 5584243    1
# 5598584    1
# 5602682    1
# 5771266    1
# Name: AppointmentID, Length: 110527, dtype: int64
# F    71840
# M    38687
# Name: Gender, dtype: int64
# 2016-05-06T07:09:54Z    24
# 2016-05-06T07:09:53Z    23
# 2016-04-25T17:18:27Z    22
# 2016-04-25T17:17:46Z    22
# 2016-04-25T17:17:23Z    19
# 2016-04-25T17:19:03Z    15
# 2016-05-10T08:18:24Z    15
# 2016-05-31T09:54:52Z    15
# 2016-05-03T07:52:31Z    14
# 2016-06-07T16:15:14Z    14
# 2016-05-25T09:36:45Z    13
# 2016-05-10T08:29:24Z    13
# 2016-03-29T10:44:23Z    13
# 2016-05-09T08:07:11Z    13
#  39     1536
#  37     1533
#  54     1530
#  34     1526
#  33     1524
#  30     1521
#  6      1521
#  3      1513
#  17     1509
#  32     1505
#  5      1489
#  44     1487
#  18     1487
#  58     1469
#  46     1460
#  45     1453
#         ...
#  74      602
#  76      571
#  75      544
#  78      541
#  77      527
#  80      511
#  81      434
#  82      392
#  79      390
#  84      311
#  83      280
#  85      275
#  86      260
#  87      184
#  89      173
#  88      126
#  90      109
#  92       86
#  91       66
#  93       53
#  94       33
#  95       24
#  96       17
#  97       11
#  98        6
#  115       5
#  100       4
#  102       2
#  99        1
# -1         1
# Name: Age, Length: 104, dtype: int64
# JARDIM CAMBURI                 7717
# MARIA ORTIZ                    5805
# RESISTÊNCIA                    4431
# JARDIM DA PENHA                3877
# ITARARÉ                        3514
# CENTRO                         3334
# TABUAZEIRO                     3132
# SANTA MARTHA                   3131
# JESUS DE NAZARETH              2853
# BONFIM                         2773
# SANTO ANTÔNIO                  2746
# SANTO ANDRÉ                    2571
# CARATOÍRA                      2565
# JABOUR                         2509
# SÃO PEDRO                      2448
# ILHA DO PRÍNCIPE               2266
# NOVA PALESTINA                 2264
# ANDORINHAS                     2262
# DA PENHA                       2217
# ROMÃO                          2215
# GURIGICA                       2018
# SÃO JOSÉ                       1977
# BELA VISTA                     1907
# MARUÍPE                        1902
# FORTE SÃO JOÃO                 1889
# ILHA DE SANTA MARIA            1885
# SÃO CRISTÓVÃO                  1836
# REDENÇÃO                       1553
# SÃO BENEDITO                   1439
# JOANA D´ARC                    1427
#                                ...
# SANTOS REIS                     547
# ESTRELINHA                      538
# SANTA CLARA                     506
# SOLON BORGES                    469
# PIEDADE                         452
# SANTA CECÍLIA                   448
# SANTA LÚCIA                     438
# SANTA LUÍZA                     428
# BARRO VERMELHO                  423
# DO MOSCOSO                      413
# MÁRIO CYPRESTE                  371
# BOA VISTA                       312
# COMDUSA                         310
# DE LOURDES                      305
# ARIOVALDO FAVALESSA             282
# ANTÔNIO HONÓRIO                 271
# FRADINHOS                       258
# ENSEADA DO SUÁ                  235
# SANTA HELENA                    178
# HORTO                           175
# UNIVERSITÁRIO                   152
# SEGURANÇA DO LAR                145
# NAZARETH                        135
# MORADA DE CAMBURI                96
# PONTAL DE CAMBURI                69
# ILHA DO BOI                      35
# ILHA DO FRADE                    10
# AEROPORTO                         8
# ILHAS OCEÂNICAS DE TRINDADE       2
# PARQUE INDUSTRIAL                 1
# Name: Neighbourhood, Length: 81, dtype: int64
# 0    99666
# 1    10861
# Name: Scholarship, dtype: int64
# 0    88726
# 1    21801
# Name: Hipertension, dtype: int64
# 0    102584
# 1      7943
# Name: Diabetes, dtype: int64
# 0    107167
# 1      3360
# Name: Alcoholism, dtype: int64
# 0    108286
# 1      2042
# 2       183
# 3        13
# 4         3
# Name: Handcap, dtype: int64
# 0    75045
# 1    35482
# Name: SMS_received, dtype: int64
# No     88208
# Yes    22319
# Name: No-show, dtype: int64

# %% [markdown]
# - in `Age` column there is a value of '-1' for only one record.
#
# - in `Handcap` column there are values of 0, 1, 2, 3, 4 rather than only 0 for not handicapped and 1 for handicapped
# and there is a typo in the column name so we will change it to be 'Handicap'.
#
# - since the `No-show` is the only column with Yes and No values rather than 0 and 1, also its terminology may cause
# some confusion we will change its name to be more clear.

# %%
df.describe()
# Out:
#           PatientId  AppointmentID            Age    Scholarship  \
# count  1.105270e+05   1.105270e+05  110527.000000  110527.000000
# mean   1.474963e+14   5.675305e+06      37.088874       0.098266
# std    2.560949e+14   7.129575e+04      23.110205       0.297675
# min    3.921784e+04   5.030230e+06      -1.000000       0.000000
# 25%    4.172614e+12   5.640286e+06      18.000000       0.000000
# 50%    3.173184e+13   5.680573e+06      37.000000       0.000000
# 75%    9.439172e+13   5.725524e+06      55.000000       0.000000
# max    9.999816e+14   5.790484e+06     115.000000       1.000000
#
#         Hipertension       Diabetes     Alcoholism        Handcap  \
# count  110527.000000  110527.000000  110527.000000  110527.000000
# mean        0.197246       0.071865       0.030400       0.022248
# std         0.397921       0.258265       0.171686       0.161543
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       4.000000
#
#         SMS_received
# count  110527.000000
# mean        0.321026
# std         0.466873
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         1.000000

# %% [markdown]
# ### Summery of found issues:
# - `ScheduledDay` and `AppointmentDay` columns are of object type rather than datetime type.
# - in `Age` column there is a value of '-1' for only one record.
# - in `Handcap` column there are values of 0, 1, 2, 3, 4 rather than only 0 for not handicapped and 1 for handicapped and there is a typo in the column name so we will change it to be 'Handicap'.
# - small typo is `Hipertension` column name rather than 'Hypertension'.
# - `No-show` is the only column with Yes and No values rather than 0 and 1, also its terminology may cause some confusion so we will change its name to be more clear.

# %% [markdown]
# <a id='clean'></a>
# ### Data Cleaning
# > In this section we will clean our dataset based on the quality & tidiness issues that we found from the previous section.

# %%
# Before moving forward we need to make a copy of the dataframe to save our cleaned dataframe in.
df_cleaned = df.copy()

# %% [markdown]
# ##### Change `ScheduledDay` and `AppointmentDay` columns to datetime type.

# %%
# we can see that they are of object type.
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null object
# AppointmentDay    110527 non-null object
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df_cleaned.ScheduledDay=pd.to_datetime(df_cleaned.ScheduledDay)
df_cleaned.AppointmentDay=pd.to_datetime(df_cleaned.AppointmentDay)

# %%
# now they are of datatime type.
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
# PatientId         110527 non-null float64
# AppointmentID     110527 non-null int64
# Gender            110527 non-null object
# ScheduledDay      110527 non-null datetime64[ns]
# AppointmentDay    110527 non-null datetime64[ns]
# Age               110527 non-null int64
# Neighbourhood     110527 non-null object
# Scholarship       110527 non-null int64
# Hipertension      110527 non-null int64
# Diabetes          110527 non-null int64
# Alcoholism        110527 non-null int64
# Handcap           110527 non-null int64
# SMS_received      110527 non-null int64
# No-show           110527 non-null object
# dtypes: datetime64[ns](2), float64(1), int64(8), object(3)
# memory usage: 11.8+ MB

# %% [markdown]
# #### Drop patient with `Age` of '-1' value.

# %%
# the patient with '-1' age value
df_cleaned[df_cleaned.Age==-1]
# Out:
#           PatientId  AppointmentID Gender        ScheduledDay AppointmentDay  \
# 99832  4.659432e+14        5775010      F 2016-06-06 08:58:13     2016-06-06
#
#        Age Neighbourhood  Scholarship  Hipertension  Diabetes  Alcoholism  \
# 99832   -1         ROMÃO            0             0         0           0
#
#        Handcap  SMS_received No-show
# 99832        0             0      No

# %%
# drop the row of this patient using its index.
df_cleaned.drop(index=df_cleaned.query('Age==-1').index,inplace=True)

# %%
# now checking if he exists anymore.
df_cleaned.query('Age==-1').any().sum()
# Out:
# 0

# %% [markdown]
# ##### Drop any value other than 0 or 1 in `Handcap` column and correct it to be 'Handicap'.
# > Since we don't have enough information to tell if patients with other values than 0 and 1 in `Handcap` column are handicapped or not.

# %%
# patients having 2, 3 or 4 in `Handcap` column.
df_cleaned[(df_cleaned.Handcap != 1) & (df_cleaned.Handcap != 0) ]
# Out:
#            PatientId  AppointmentID Gender        ScheduledDay AppointmentDay  \
# 946     7.282582e+13        5582483      M 2016-04-14 09:26:08     2016-04-29
# 1665    1.242919e+13        5525497      M 2016-03-30 09:16:41     2016-04-29
# 1666    1.242919e+13        5525498      M 2016-03-30 09:16:41     2016-04-29
# 2071    1.242919e+13        5640120      M 2016-04-29 10:08:48     2016-04-29
# 2091    1.491829e+13        5638626      F 2016-04-29 08:13:59     2016-04-29
# 2213    3.423831e+09        5640766      F 2016-04-29 11:22:50     2016-04-29
# 101912   84       RESISTÊNCIA            0             1         0
# 101913   84       RESISTÊNCIA            0             1         0
# 101949   12        ESTRELINHA            0             0         0
# 102276   89        BELA VISTA            0             1         1
# 102360   44             ROMÃO            0             1         1
# 102955   15       JOANA D´ARC            1             0         0
# 104268    9           ITARARÉ            0             0         0
# 104927   70        ANDORINHAS            0             0         0
# 104931   70        ANDORINHAS            0             0         0
# 104932   70        ANDORINHAS            0             0         0
# 105008   37       SANTO ANDRÉ            0             0         0
# 105073   35        BELA VISTA            1             0         1
# 105322    6       SANTA CLARA            0             0         0
# 105753   32          REDENÇÃO            0             0         0
# 108335   45             ROMÃO            0             0         0
# 108376   44             ROMÃO            0             1         1
# 109484   64          DA PENHA            0             1         1
# 109733   34       JUCUTUQUARA            0             0         0
# 109975   39      PRAIA DO SUÁ            1             0         0
# 110107   44       RESISTÊNCIA            0             0         0
#
#         Alcoholism  Handcap  SMS_received No-show
# 946              0        2             1      No
# 1665             1        2             1      No
# 1666             1        2             0      No
# 2071             1        2             0      No
# 2091             0        2             0      No
# 2213             0        2             0      No
# 2214             0        3             0      No
# 2673             0        2             1      No
# 5424             1        2             0     Yes
# 5467             0        2             0      No
# 5475             0        2             0     Yes
# 5485             0        2             0      No
# 5510             0        2             0      No
# 6067             0        2             0     Yes
# 6156             0        2             0      No
# 6401             0        2             0      No
# 11227            0        2             0      No
# 11230            0        2             0      No
# 14847            0        2             1      No
# 15839            0        2             1      No
# 15845            0        2             0      No
# 16632            0        2             0      No
# 16634            0        2             0     Yes
# 16635            0        2             0      No
# 16636            0        2             0     Yes
# 17862            0        2             0      No
# 18241            0        2             1      No
# 19264            0        2             1     Yes
# 19915            0        2             1      No
# 19981            0        2             0      No
# ...            ...      ...           ...     ...
# 96173            0        2             0      No
# 96457            0        2             0      No
# 96831            0        2             0      No
# 97998            0        2             0      No
# 98045            0        2             0      No
# 98538            0        4             0      No
# 99455            0        2             0      No
# 100538           0        2             0      No
# 101074           0        2             0      No
# 101911           0        2             0     Yes
# 101912           0        2             0      No
# 101913           0        2             0     Yes
# 101949           0        2             0     Yes
# 102276           0        2             0      No
# 102360           0        2             0      No
# 102955           0        2             0      No
# 104268           0        4             1     Yes
# 104927           1        3             0      No
# 104931           1        3             0      No
# 104932           1        3             0      No
# 105008           0        2             0      No
# 105073           0        2             1      No
# 105322           0        2             0      No
# 105753           0        2             0      No
# 108335           0        2             1      No
# 108376           0        2             1      No
# 109484           0        2             0      No
# 109733           0        2             1      No
# 109975           0        2             1      No
# 110107           0        2             1      No
#
# [199 rows x 14 columns]

# %%
df_cleaned.Handcap.value_counts()
# Out:
# 0    108285
# 1      2042
# 2       183
# 3        13
# 4         3
# Name: Handcap, dtype: int64

# %%
# drop these patients by using the index of their rows.
df_cleaned.drop(index=df_cleaned.query('(Handcap!=1) & (Handcap!=0)').index,inplace=True)

#Correct the column name.
df_cleaned.rename(columns={"Handcap": "Handicap"},inplace=True)

# %%
# check for any value other than 0 or 1 in `Handicap` column
df_cleaned.Handicap.value_counts()
# Out:
# 0    108285
# 1      2042
# Name: Handicap, dtype: int64

# %% [markdown]
# ##### Rename `Hipertension` column as 'Hypertension'.

# %%
#check for the old name of the column
df_cleaned.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hipertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMS_received', 'No-show'],
#       dtype='object')

# %%
df_cleaned.rename(columns={"Hipertension": "Hypertension"},inplace=True)

# %%
# now check for the new name of the column
df_cleaned.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hypertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMS_received', 'No-show'],
#       dtype='object')

# %% [markdown]
# ##### Rename `No-show` column as 'Showed' with replacement of No to be 1 and Yes to be 0.

# %%
# values of the old column.
df_cleaned['No-show'].value_counts()
# Out:
# No     88049
# Yes    22278
# Name: No-show, dtype: int64

# %%
# rename the column with a clearer name and change the values to the corrosponding name of the new column.
df_cleaned.rename(columns={"No-show": "Showed"},inplace=True)
df_cleaned.Showed.replace(['No','Yes'],[1,0],inplace=True)

# %%
# values of the new column.
# Note: now the patient who showed up will have a value of 1 in `Showed` column and 0 if they didn't show up.
df_cleaned.Showed.value_counts()
# Out:
# 1    88049
# 0    22278
# Name: Showed, dtype: int64

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
# > Now in this section of our analysis we try to ask questions to seek out the affecting factors and characteristics of the patients who are most likely to not show to their appointment.

# %% [markdown]
# ### Question 1: What hour, weekday, month and date did patients usually schedule their appointment(s) at/on?

# %%
# select the hour that the patient scheduled his/her appointment at from `ScheduledDay` column.
scheduled_hour = df_cleaned.ScheduledDay.dt.hour.value_counts()
scheduled_hour
# Out:
# 7     19192
# 8     15326
# 9     12792
# 10    11032
# 14     9112
# 13     9018
# 11     8439
# 15     8054
# 16     5536
# 12     5412
# 17     2908
# 6      1576
# 18     1339
# 19      488
# 20      100
# 21        3
# Name: ScheduledDay, dtype: int64

# %%
# plot the scheduled_hour
scheduled_hour.sortlevel().plot(kind='bar',figsize=(12, 6))
plt.xlabel('Scheduled Hour')
plt.ylabel('No. of Scheduled Appointments')
plt.title('No. of Scheduled Appointments vs. Scheduled Hour');
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: FutureWarning: sortlevel is deprecated, use sort_index(level=...)

# %% [markdown]
# >This graph shows the activity distribution of scheduled appointment hours. Clearly, we can notice that patient usually schedule their appointments in the morning most likely from 7 am to 10 am as the number of scheduled decreases in the afternoon period and become very rare to schedule their appointments after 7 pm.

# %%
scheduled_weekday = df_cleaned.ScheduledDay.dt.weekday_name.value_counts()
scheduled_weekday
# Out:
# Tuesday      26111
# Wednesday    24223
# Monday       23044
# Friday       18881
# Thursday     18044
# Saturday        24
# Name: ScheduledDay, dtype: int64

# %%
scheduled_month = df_cleaned.ScheduledDay.dt.month.value_counts()
scheduled_month
# Out:
# 5     67295
# 4     25299
# 6     13723
# 3      3608
# 2       280
# 12       61
# 1        60
# 11        1
# Name: ScheduledDay, dtype: int64

# %%
scheduled_date = df_cleaned.ScheduledDay.dt.date.value_counts()
scheduled_date
# Out:
# 2016-05-03    4226
# 2016-05-02    4207
# 2016-05-16    4110
# 2016-05-05    4088
# 2016-05-10    4017
# 2016-05-09    3964
# 2016-04-29    3772
# 2016-05-11    3570
# 2016-05-04    3562
# 2016-05-30    3446
# 2016-05-17    3440
# 2016-05-24    3416
# 2016-05-06    3408
# 2016-05-12    3399
# 2016-05-18    3372
# 2016-05-19    3114
# 2016-05-20    3101
# 2016-05-13    3088
# 2016-05-25    2915
# 2016-05-31    2839
# 2016-06-01    2771
# 2016-06-02    2753
# 2016-04-28    2705
# 2016-06-03    2493
# 2016-04-26    2427
# 2016-06-06    2398
# 2016-04-27    2326
# 2016-04-25    2107
# 2016-04-20    1949
# 2016-06-07    1771
#               ...
# 2016-02-18       9
# 2016-01-11       7
# 2015-12-15       7
# 2016-02-11       7
# 2016-01-22       6
# 2016-04-30       6
# 2015-12-14       6
# 2016-01-25       5
# 2016-01-05       4
# 2016-02-02       4
# 2016-01-14       3
# 2016-02-04       3
# 2016-01-21       3
# 2016-02-03       3
# 2016-01-20       2
# 2016-05-07       2
# 2016-01-28       1
# 2016-01-04       1
# 2015-12-03       1
# 2016-01-13       1
# 2016-01-27       1
# 2016-01-26       1
# 2015-11-10       1
# 2016-01-19       1
# 2016-03-05       1
# 2016-03-19       1
# 2016-06-04       1
# 2016-04-09       1
# 2016-04-16       1
# 2016-02-15       1
# Name: ScheduledDay, Length: 111, dtype: int64

# %% [markdown]
# >  Based on our dataset, we find that May had the most no. of scheduled appointments especially on May 3rd with 4226 appointments.

# %% [markdown]
# ### Question 2: What weekday, month and date are associated with the highest number of absent patients?

# %%
# select the weekday that the patient scheduled his/her appointment at from `ScheduledDay` column.
absent_weekday = df_cleaned.query('Showed==0').AppointmentDay.dt.weekday_name.value_counts()
absent_weekday
# Out:
# Tuesday      5136
# Wednesday    5084
# Monday       4681
# Friday       4033
# Thursday     3335
# Saturday        9
# Name: AppointmentDay, dtype: int64

# %%
# taking the labels or x-axis to be the index of scheduled_weekday
labels = scheduled_weekday.index

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars


fig, ax = plt.subplots(figsize=(12,6))
rects1 = ax.bar(x - width/2, scheduled_weekday, width, label='Scheduled Appointments')
rects2 = ax.bar(x + width/2, absent_weekday, width, label='No-Shows Appointments')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Weekday')
ax.set_ylabel('No. of Appointments')
ax.set_title('No. of Appointments vs. Weekdays')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Show the value of each bar above the bar itself.
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# > Using the above graph we can compare with no. scheduled appointments and no. no-shows appointments on weekdays.
# This graph shows that patient tend to schedule their appointment on Tuesdays, as well as the highest no. of no-shows appointments, happen to be on Tuesdays also and less likely to schedule their appointment or show-up on Thursdays
#
# > *Considering Saturday to be a weekend*

# %%
absent_month = df_cleaned.query('Showed==0').AppointmentDay.dt.month.value_counts()
absent_month
# Out:
# 5    16767
# 6     4878
# 4      633
# Name: AppointmentDay, dtype: int64

# %%
# taking the labels or x-axis to be the index of scheduled_month
# note that scheduled_month only have 3 months while absent_month have 8 months (5 of them have no-shows appointments)
labels = scheduled_month[0:3].index

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(12,6))
rects1 = ax.bar(x - width/2, scheduled_month[:3], width, label='Scheduled Appointments')
rects2 = ax.bar(x + width/2, absent_month, width, label='No-Shows Appointments')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Month No.')
ax.set_ylabel('No. of Appointments')
ax.set_title('No. of Appointments vs. Month No.')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

# Show the value of each bar above the bar itself.
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects:
        height = rect.get_height()
        ax.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')


autolabel(rects1)
autolabel(rects2)

fig.tight_layout()

plt.show()

# %% [markdown]
# > Using the above graph we can compare with no. scheduled appointments and no. no-shows appointments on different months.
# This graph shows that patients tend to schedule their appointment on May, as well as the highest no. of no-shows appointments, happen to be in May also and less likely to schedule their appointment or show-up in June.
#
# > Very interesting find is that neither NOV, DEC, JAN, FEB nor MAR had any no-shows appointments despite there were 4 thousand appointments scheduled in these months.

# %%
absent_date = df_cleaned.query('Showed==0').AppointmentDay.dt.date.value_counts()
absent_date
# Out:
# 2016-05-16    1047
# 2016-05-09    1015
# 2016-05-10     990
# 2016-05-04     972
# 2016-05-17     932
# 2016-05-13     903
# 2016-05-20     897
# 2016-05-19     891
# 2016-05-30     887
# 2016-05-18     887
# 2016-05-11     883
# 2016-06-06     873
# 2016-05-02     859
# 2016-05-12     837
# 2016-05-03     828
# 2016-06-07     814
# 2016-06-01     812
# 2016-05-24     808
# 2016-05-05     806
# 2016-06-03     805
# 2016-06-02     801
# 2016-05-06     795
# 2016-06-08     773
# 2016-05-31     764
# 2016-05-25     757
# 2016-04-29     633
# 2016-05-14       9
# Name: AppointmentDay, dtype: int64

# %% [markdown]
# > The above finding clearly emphasizes that most no-shows appointments happened in May with 1046 no-shows appointments on May 16th alone.

# %% [markdown]
# ### Question 3: Which gender is more likely to not show up to their appointment?

# %%
# Group the df by 'Gender' then choose `Showed` column and calculate the percentage of each case and save it as df called 
# 'gender'
gender=df_cleaned.groupby('Gender').Showed.value_counts().to_frame()
gender.rename(columns={"Showed":"No. of Appointments"},inplace=True)
gender['Perc']= df_cleaned.groupby('Gender').Showed.value_counts(normalize=True,sort = False)*100
gender
# Out:
#                No. of Appointments       Perc
# Gender Showed
# F      1                     57162  79.690506
#        0                     14568  20.309494
# M      1                     30887  80.024354
#        0                      7710  19.975646

# %%
# now plot `gender` df .
gender.Perc.plot(kind= "barh", stacked=True, colormap='Accent',figsize=(12,6))
for  location,value in enumerate(gender.Perc):
    plt.text(value,location, str(value)[0:5])
plt.xlabel('Appointments Percentage')
plt.title("Appointments Percentage vs. Gender Showed/didn't Show Patient");

# %% [markdown]
# > Based on the above graph, the percentage of female patients who didn't show up is slightly higher than men patients. This finding can let us confidently say that the gender of the patient has nothing to do with the patient showing up or not, which can lead us to the following question.

# %% [markdown]
# ### Question 4: Does the gender of the patient with scholarship related to patients who didn't show up to their appointments?

# %%
# Group the df by 'Gender' and 'Scholarship' then choose `Showed` column and calculate the percentage of each case 
# and save it as df called 'gender_scholarship'
gender_scholarship=df_cleaned.groupby(['Gender','Scholarship']).Showed.value_counts().to_frame()
gender_scholarship.rename(columns={"Showed":"No. of Appointments"},inplace=True)
gender_scholarship['Perc']= df_cleaned.groupby(['Gender','Scholarship']).Showed.value_counts(normalize=True,sort = False)*100
gender_scholarship
# Out:
#                            No. of Appointments       Perc
# Gender Scholarship Showed
# F      0           1                     50428  80.184449
#                    0                     12462  19.815551
#        1           1                      6734  76.176471
#                    0                      2106  23.823529
# M      0           1                     29355  80.218069
#                    0                      7239  19.781931
#        1           1                      1532  76.485272
#                    0                       471  23.514728

# %%
# now plot `gender_scholarship` df .
gender_scholarship.Perc.plot(kind= "barh", stacked=True, colormap='Paired',figsize=(12,6))
for  location,value in enumerate(gender_scholarship.Perc):
    plt.text(value,location, str(value)[0:5])
plt.xlabel('Appointments Percentage')
plt.title("Appointments Percentage vs. Gender of the Showed/didn't Show Patient who have/haven't Scholarship");

# %% [markdown]
# > In this question we try to answer if the patients with the scholarship will affect the gender of the patient who showed up to his/her appointment.
# > despite the small variations between males and females percentages we find that percentage of patients with a scholarship who didn't show up for their appointments are **4% higher** than the percentage of patients without a scholarship who didn't show up for their appointments which is very interesting leading us to think more about the seriousness of patients with scholarship despite their gender.

# %% [markdown]
# ### Question 5: Does receiving an SMS message would give an indication that the patient will show up to the appointment and vice versa?

# %%
sms=df_cleaned.groupby('SMS_received').Showed.value_counts().to_frame()
sms.rename(columns={"Showed":"No. of Appointments"},inplace=True)
sms['Perc']= df_cleaned.groupby('SMS_received').Showed.value_counts(normalize=True,sort = False)*100
sms
# Out:
#                      No. of Appointments       Perc
# SMS_received Showed
# 0            1                     62389  83.305293
#              0                     12503  16.694707
# 1            1                     25660  72.414280
#              0                      9775  27.585720

# %%
sms.Perc.plot(kind= "barh", stacked=True, colormap='Dark2',figsize=(12,6))
for  location,value in enumerate(sms.Perc):
    plt.text(value,location, str(value)[0:5])
plt.xlabel('Appointments Percentage')
plt.title("Appointments Percentage vs. Showed/didn't Show Patient who Received/didn't Receive SMS");

# %% [markdown]
# > One of the most interesting findings of our analysis is that 83.3% of patient who didn't receive any SMS showed up to their appointment, knowing that there were 72.41% of patients who received SMS showed up to their appointment which tells us that sending SMS to patients can lead to roughly 11% more showed up patients to their appointments.

# %% [markdown]
# ### Question 6: Are handicapped patients less likely to show up to their appointments?

# %%
handicapped=df_cleaned.groupby('Handicap').Showed.value_counts().to_frame()
handicapped.rename(columns={"Showed":"No. of Appointments"},inplace=True)
handicapped['Perc']= df_cleaned.groupby('Handicap').Showed.value_counts(normalize=True,sort = False)*100
handicapped
# Out:
#                  No. of Appointments       Perc
# Handicap Showed
# 0        1                     86373  79.764510
#          0                     21912  20.235490
# 1        1                      1676  82.076396
#          0                       366  17.923604

# %%
handicapped.Perc.plot(kind= "barh", stacked=True, colormap='Set1',figsize=(12,6))
for  location,value in enumerate(handicapped.Perc):
    plt.text(value,location, str(value)[0:5])
plt.xlabel('Appointments Percentage')
plt.title("Appointments Percentage vs. Showed/didn't Show Handicapped Patients");

# %% [markdown]
# > The above graph clearly shows that the percentage of not showing for not handicapped patients are 2.2% higher that the percentage of not showing for handicapped patients which means that handicapped patients are more likely to show up to their appointments.

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# > As we discussed our findings from the Exploratory Data Analysis section we can conclude the following:
# - Gender of the patient has almost no effect on the patient not showing to the appointment.
# - Gender of the patient with a scholarship has almost no effect on the patient not showing to the appointment but patients with a scholarship (no matter what their gender is) are more likely to not show up than those with no scholarship.
# - SMS messages definitely help 11% more patients to show up to their appointments than patients that didn't receive any SMS.
# - Finally, Handicapped patients are 2.2% more likely to show up to their appointments than patients who aren't handicapped .

# %%
from subprocess import call
call(['python', '-m', 'nbconvert', 'Investigate_a_Dataset.ipynb'])
# Out:
# 0
